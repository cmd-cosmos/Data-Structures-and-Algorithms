# %%
lst = [1,9,8,5,7,2,1,3,0,9,6,5,2]

lst.sort()
lst
# Out:
# [0, 1, 1, 2, 2, 3, 5, 5, 6, 7, 8, 9, 9]

# %%
lst2 = [1,9,8,5,7,2,1,3,0,9,6,5,2]

lst3 = sorted(lst2)
lst3
# Out:
# [0, 1, 1, 2, 2, 3, 5, 5, 6, 7, 8, 9, 9]
