# %%
### basic bst implementation and dfs traversal

class Node:
    def __init__(self, data) -> None:
        self.data  = data
        self.left  = None
        self.right = None

# %%
# type: ignore

class BST:
    def __init__(self) -> None:
        self.root = None

    def insert(self, data):
        if self.root is None:
            self.root = Node(data=data)
        else:
            self._insert(self.root, data)

    def _insert(self, node, data):
        if data < node.data:
            if node.left is None:
                node.left = Node(data=data)
            else:
                self._insert(node.left, data=data)
        elif data > node.data:
            if node.right is None:
                node.right = Node(data=data)
            else:
                self._insert(node.right, data=data)
            
    ### dfs --> pre, in, post order traversal

    def preorder(self):
        res = []

# %%
bst = BST()

for val in range(20):
    bst.insert(val)

# %%
# from PrettyPrint import PrettyPrintTree

# pt = PrettyPrintTree(lambda x: [x.left, x.right], lambda x: x.data)
# pt(bst.root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 from PrettyPrint import PrettyPrintTree
#       3 pt = PrettyPrintTree(lambda x: [x.left, x.right], lambda x: x.data)
# ----> 4 pt(bst.root)
#
# File c:\Python313\Lib\site-packages\PrettyPrint\PrintTree\TreePrinter.py:82, in PrettyPrintTree.__call__(self, node, get_children, get_val, get_label, label_color, show_newline_literal, newline_literal, return_instead_of_print, trim, trim_symbol, start_message, color, border, max_depth, orientation)
#      48 def __call__(
#      49         self,
#      50         node: T,
#    (...)     65         orientation: bool = None,
#      66 ):
#      67     tree_formatter = TreeFormatter(
#      68         get_children=get_children or self.default_get_children,
#      69         get_val=get_val or self.default_get_node_val,
#    (...)     80         orientation=self.default_orientation if orientation is None else orientation,
#      81     )
# ---> 82     res = tree_formatter.format(node)
#      83     if return_instead_of_print or (return_instead_of_print is None and self.default_dont_print):
#      84         return res
#
# File c:\Python313\Lib\site-packages\PrettyPrint\PrintTree\TreeFormatter.py:45, in TreeFormatter.format(self, node)
#      43 def format(self, node: T) -> str:
#      44     if self.orientation == Orientation.Vertical:
# ---> 45         res = self.tree_vertical_join(node)
#      46     else:
#      47         res = self.tree_horizontal_join(node)
#
# File c:\Python313\Lib\site-packages\PrettyPrint\PrintTree\TreeFormatter.py:59, in TreeFormatter.tree_vertical_join(self, node, depth)
#      56 node = self.add_styles(node)
#      57 if children and (self.max_depth == -1 or depth < self.max_depth):
#      58     children = [
# ---> 59         self.tree_vertical_join(child, depth + 1)
#      60         for child in children
#      61     ]
#      62     if len(children) == 1:
#      63         children_node = children[0]
#
# File c:\Python313\Lib\site-packages\PrettyPrint\PrintTree\TreeFormatter.py:55, in TreeFormatter.tree_vertical_join(self, node, depth)
#      53 def tree_vertical_join(self, node: T, depth: int = 0) -> NodeFormatter:
#      54     label = self.get_label(node) if self.get_label else None
# ---> 55     children = self.get_children(node)
#      56     node = self.add_styles(node)
#      57     if children and (self.max_depth == -1 or depth < self.max_depth):
#
# Cell In[9], line 3, in <lambda>(x)
#       1 from PrettyPrint import PrettyPrintTree
# ----> 3 pt = PrettyPrintTree(lambda x: [x.left, x.right], lambda x: x.data)
#       4 pt(bst.root)
#
# AttributeError: 'NoneType' object has no attribute 'left'
