# %%
s = "Batman"

print(s[0])    # B
print(s[-1])   # n
print(s[2:5])  # tma
print(s[::-1]) # reverse string
# Out:
# B
# n
# tma
# namtaB

# %%
# char freq calc - using Counter

from collections import Counter

s1 = "Batmann"
freq = Counter(s1)

freq
# Out:
# Counter({'a': 2, 'n': 2, 'B': 1, 't': 1, 'm': 1})

# %%
def freq_ct(string):
    ctr = {}
    for char in s1:
        if char not in ctr:
            ctr[char] = 1
        else:
            ctr[char] += 1
    return ctr

print(freq_ct(s1))
# Out:
# {'B': 1, 'a': 2, 't': 1, 'm': 1, 'n': 2}
