# %%
#type: ignore
from typing import Any, Optional

class Node:
    def __init__(self, data: Any) -> None:
        self.data: Any = data
        self.next: Optional['Node'] = None
        self.prev: Optional['Node'] = None

# %%
class DoublyLinkedList:
    def __init__(self) -> None:
        self.head: Optional['Node'] = None
        self.contents: list[Any]    = []
        self.__size: int          = 0

    def isEmpty(self) -> bool:
        return not self.__size
    
    def insertNode(self, data: Any):
        newNode: Node = Node(data=data)

        if self.head:
            curr = self.head
            while curr.next:
                curr = curr.next
            temp = curr
            curr.next = newNode
            newNode.prev = temp 
            self.__size += 1
            self.contents.append(data)
        else:
            self.head = newNode
            self.__size += 1
            self.contents.append(data)
            return

# %%
dll = DoublyLinkedList()

# %%
dll.isEmpty()
# Out:
# True

# %%
dll.insertNode(10)
dll.insertNode(20)
dll.insertNode(30)
dll.insertNode(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 dll.insertNode(10)
# ----> 2 dll.insertNode(20)
#       3 dll.insertNode(30)
#       4 dll.insertNode(40)
#
# Cell In[27], line 15, in DoublyLinkedList.insertNode(self, data)
#      13 if self.head:
#      14     curr = self.head
# ---> 15     while curr.next:
#      16         curr = curr.next
#      17     temp = curr
#
# AttributeError: 'int' object has no attribute 'next'
